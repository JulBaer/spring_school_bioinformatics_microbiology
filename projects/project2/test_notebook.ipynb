# %% [markdown]
# # Testing Conda Environment
# Below we try to import all packages we will need. This can take a while, but hopefully it should not give an error message.

# %%
3*3
# Out:
# 9

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %gui qt


import os
import pathlib
import h5py
import json


import numpy as np
import pandas as pd

import tifffile

from scipy import ndimage as ndi

from dask_image.imread import imread
import dask.array as da

import skimage.segmentation as segmentation 
import skimage.filters as filters
from skimage.feature import peak_local_max
from skimage.measure import label, regionprops, regionprops_table
from skimage import morphology
from skimage import data


import sys
sys.path.append('D:\GitHub\delta')
import delta

from pybacmman.selections import saveAndOpenSelection

import napari
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

#set plot options to get nicer figures
plt.rcParams['figure.figsize'] = [12, 4]
plt.rcParams['figure.dpi'] = 100

# %% [markdown]
# ## A simple test
# Below we will plot a simple quadratic function. If the installation worked correctly, you should see a figure with a plot of this function

# %%
#a simple test of numpy
x = np.arange(-10,11)
y = x**2
plt.plot(x,y)

# %% [markdown]
# ## A more complex test
# Below we will try to open Napari, if it works (again loading can take a while) it should open a new window with an image of an astronaut.

# %%
viewer = napari.view_image(data.astronaut(), rgb=True)

# %%
for p in sys.path: print(p)
# Out:
# D:\GitHub\sib-im\projects\project2
# C:\Users\julia\anaconda3\envs\project2\python39.zip
# C:\Users\julia\anaconda3\envs\project2\DLLs
# C:\Users\julia\anaconda3\envs\project2\lib
# C:\Users\julia\anaconda3\envs\project2
#
# C:\Users\julia\anaconda3\envs\project2\lib\site-packages
# C:\Users\julia\anaconda3\envs\project2\lib\site-packages\win32
# C:\Users\julia\anaconda3\envs\project2\lib\site-packages\win32\lib
# C:\Users\julia\anaconda3\envs\project2\lib\site-packages\Pythonwin
# D:\GitHub\delta

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 delta -h
#
# NameError: name 'h' is not defined

# %%
delta.assets.download_assets()
# Out:
# Download latest models? [y/n]:  y
# Models will be downloaded to D:\GitHub\delta\delta\assets\models
# Downloading model: unet_moma_seg... Done
# Downloading model: unet_moma_track... Done
# Downloading model: unet_pads_seg... Done
# Downloading model: unet_pads_track... Done
# Downloading model: unet_momachambers_seg... Done
# Download latest training sets? [y/n]:  y
# Training sets will be downloaded and unzipped to D:\GitHub\delta\delta\assets\trainingsets
# Downloading zip: D:\GitHub\delta\delta\assets\trainingsets\2D.zip... Done
# Extracting to D:\GitHub\delta\delta\assets\trainingsets\2D...
# ---------------------------------------------------------------------------
# ReadError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 delta.assets.download_assets()
#
# File D:\GitHub\delta\delta\assets.py:95, in download_assets(load_models, load_sets, load_evals, config_level)
#      91 sets_dir = load_sets if isinstance(load_sets, str) else None
#      92 load_sets = (
#      93     _ask("Download latest training sets?") if load_sets is None else bool(load_sets)
#      94 )
# ---> 95 sets_files = _download_training_sets(sets_dir=sets_dir) if load_sets else dict()
#      97 # Should we download evaluation movies?
#      98 movies_dir = load_evals if isinstance(load_evals, str) else None
#
# File D:\GitHub\delta\delta\assets.py:256, in _download_training_sets(sets_ids, sets_dir)
#     254     sets_files[filename] = os.path.join(sets_dir, filename)
#     255     zip_file = os.path.join(sets_dir, filename + ".zip")
# --> 256     _download_and_unzip(
#     257         google_id, zip_file, sets_files[filename], remove_previous=True
#     258     )
#     260 return sets_files
#
# File D:\GitHub\delta\delta\assets.py:302, in _download_and_unzip(id, zip_file, folder, remove_previous)
#     300 if not os.path.exists(folder):
#     301     os.makedirs(folder)
# --> 302 shutil.unpack_archive(zip_file, folder)
#     303 print(" Done")
#     305 print("Deleting archive...", end="", flush=True)
#
# File ~\anaconda3\envs\project2\lib\shutil.py:1269, in unpack_archive(filename, extract_dir, format)
#    1267 func = _UNPACK_FORMATS[format][1]
#    1268 kwargs = dict(_UNPACK_FORMATS[format][2])
# -> 1269 func(filename, extract_dir, **kwargs)
#
# File ~\anaconda3\envs\project2\lib\shutil.py:1168, in _unpack_zipfile(filename, extract_dir)
#    1165 import zipfile  # late import for breaking circular dependency
#    1167 if not zipfile.is_zipfile(filename):
# -> 1168     raise ReadError("%s is not a zip file" % filename)
#    1170 zip = zipfile.ZipFile(filename)
#    1171 try:
#
# ReadError: D:\GitHub\delta\delta\assets\trainingsets\2D.zip is not a zip file
